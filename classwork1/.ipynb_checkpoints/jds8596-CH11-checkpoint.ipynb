# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

cs = CubicSpline(x, y, bc_type='natural')

x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

coeffs = np.polyfit(x, y, 5)
poly = np.poly1d(coeffs)
y_poly = poly(x_interp)

plt.scatter(x, y)
plt.plot(x_interp, y_interp, label="CubicSpline", linewidth=2)
plt.plot(x_interp, y_poly, '--', label="Polyfit (degree 5)", linewidth=2)

plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
#Used ChatGPT to help fix mistakes and overall help
