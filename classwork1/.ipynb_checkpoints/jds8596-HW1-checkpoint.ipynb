# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
p = range(10, 1001, 20)
def MonteCarlo(p):
    counter = 0
    for i in range(0, p):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        if (x*x + y*y < 1):
            counter = counter + 1
    return 4*counter/shotstaken    
error = MonteCarlo(p) - np.pi
print(error)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-1197c53f3c77> in <module>
#      12             counter = counter + 1
#      13     return 4*counter/shotstaken
# ---> 14 error = MonteCarlo(p) - np.pi
#      15 print(error)
#
# <ipython-input-4-1197c53f3c77> in MonteCarlo(p)
#       6 def MonteCarlo(p):
#       7     counter = 0
# ----> 8     for i in range(0, p):
#       9         x = random.uniform(-1, 1)
#      10         y = random.uniform(-1, 1)
#
# TypeError: 'range' object cannot be interpreted as an integer
