# %%
n = int(input("Please enter a number: "))

binary = ""

while n > 0:
    remainder = n % 2
    binary = str(remainder) + binary
    n = n // 2

print(binary)
# Out:
# Please enter a number: 5
# 101
