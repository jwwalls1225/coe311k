# %%
I'm about to write my first Jupyter Notebook in Python
# Out:
#   File "<ipython-input-1-3937b4f909e3>", line 1
#     I'm about to write my first Jupyter Notebook in Python
#                                                           ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# I'm about to write my first Jupyter Notebook in Python

# %%
print ("Hello World")
# Out:
# Hello World
